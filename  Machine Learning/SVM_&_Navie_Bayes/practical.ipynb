# %%
#1 Question Example
import numpy as np
from math import log2
def entropy(labels):
    values, counts = np.unique(labels, return_counts=True)
    probabilities = counts / counts.sum()
    return -np.sum(probabilities * np.log2(probabilities))
def information_gain(parent, left_child, right_child):
    weight_left = len(left_child) / len(parent)
    weight_right = len(right_child) / len(parent)
    return entropy(parent) - (
        weight_left * entropy(left_child) +
        weight_right * entropy(right_child)
    )


parent_labels = np.array([1, 1, 1, 0, 0, 0])
left_labels = np.array([1, 1, 0])
right_labels = np.array([1, 0, 0])

print("Entropy of Parent:", entropy(parent_labels))
print("Information Gain:", information_gain(parent_labels, left_labels, right_labels))
# Out:
# Entropy of Parent: 1.0
# Information Gain: 0.08170416594551044

# %%
#2nd Question Example
import numpy as np
from math import log2
def entropy(labels):
    values, counts = np.unique(labels, return_counts=True)
    probabilities = counts / counts.sum()
    return -np.sum(probabilities * np.log2(probabilities))
def gini(labels):
    values, counts = np.unique(labels, return_counts=True)
    probabilities = counts / counts.sum()
    return 1 - np.sum(probabilities ** 2)

labels = np.array([1, 1, 1, 0, 0, 0])

print("Entropy:", entropy(labels))
print("Gini Impurity:", gini(labels))
# Out:
# Entropy: 1.0
# Gini Impurity: 0.5

# %%
#3d Question Example
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

data = load_iris()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

dt_pruned = DecisionTreeClassifier(max_depth=3, random_state=42)
dt_pruned.fit(X_train, y_train)


y_pred = dt_pruned.predict(X_test)

print("Accuracy with Pre-Pruning:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy with Pre-Pruning: 1.0

# %%
#4. :Write a Python program to train a Decision Tree Classifier using Gini
#Impurity as the criterion and print the feature importances (practical).
#Hint: Use criterion='gini' in DecisionTreeClassifier and access .feature_importances_.
#(Include your Python code and output in the code box below.)

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
data = load_iris()
X = data.data
y = data.target
feature_names = data.feature_names

dt = DecisionTreeClassifier(criterion='gini', random_state=42)
dt.fit(X, y)

print("Feature Importances (Gini Impurity):")
for feature, importance in zip(feature_names, dt.feature_importances_):
    print(f"{feature}: {importance:.4f}")
# Out:
# Feature Importances (Gini Impurity):
# sepal length (cm): 0.0133
# sepal width (cm): 0.0000
# petal length (cm): 0.5641
# petal width (cm): 0.4226

# %%
#5th Question Example
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
iris = load_iris()
X, y = iris.data, iris.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train SVM classifier
svm_model = SVC(kernel='linear', random_state=42)
svm_model.fit(X_train, y_train)

y_pred = svm_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
#6th Question Example
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

iris = load_iris()
X, y = iris.data, iris.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Model using RBF kernel
model = SVC(kernel='rbf', gamma='scale')
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Model Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Model Accuracy: 1.0

# %%
#7. Write a Python program to train two SVM classifiers with Linear and RBF
#kernels on the Wine dataset, then compare their accuracies.
#Hint:Use SVC(kernel='linear') and SVC(kernel='rbf'), then compare accuracy scores after fitting
#on the same dataset.
#(Include your Python code and output in the code box below.)

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
wine = load_wine()
X = wine.data
y = wine.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# SVM with Linear Kernel
svm_linear = SVC(kernel='linear', random_state=42)
svm_linear.fit(X_train, y_train)
y_pred_linear = svm_linear.predict(X_test)

# SVM with RBF Kernel
svm_rbf = SVC(kernel='rbf', gamma='scale', random_state=42)
svm_rbf.fit(X_train, y_train)
y_pred_rbf = svm_rbf.predict(X_test)

print("Linear Kernel SVM Accuracy:", accuracy_score(y_test, y_pred_linear))
print("RBF Kernel SVM Accuracy:", accuracy_score(y_test, y_pred_rbf))
# Out:
# Linear Kernel SVM Accuracy: 0.9814814814814815
# RBF Kernel SVM Accuracy: 0.7592592592592593

# %%
#8th Question Example.
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

iris = load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

y_pred = nb_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9777777777777777

# %%
#9th Question Example
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score
import numpy as np

iris = load_iris()
X, y = iris.data, iris.target

X_multinomial = np.abs(X)
X_bernoulli = (X > X.mean()).astype(int)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)
X_train_m, X_test_m, _, _ = train_test_split(
    X_multinomial, y, test_size=0.3, random_state=42
)
X_train_b, X_test_b, _, _ = train_test_split(
    X_bernoulli, y, test_size=0.3, random_state=42
)

# Gaussian Naïve Bayes
gnb = GaussianNB()
gnb.fit(X_train, y_train)
pred_g = gnb.predict(X_test)

# Multinomial Naïve Bayes
mnb = MultinomialNB()
mnb.fit(X_train_m, y_train)
pred_m = mnb.predict(X_test_m)

# Bernoulli Naïve Bayes
bnb = BernoulliNB()
bnb.fit(X_train_b, y_train)
pred_b = bnb.predict(X_test_b)

print("Gaussian NB Accuracy:", accuracy_score(y_test, pred_g))
print("Multinomial NB Accuracy:", accuracy_score(y_test, pred_m))
print("Bernoulli NB Accuracy:", accuracy_score(y_test, pred_b))
# Out:
# Gaussian NB Accuracy: 0.9777777777777777
# Multinomial NB Accuracy: 0.9555555555555556
# Bernoulli NB Accuracy: 0.7111111111111111

# %%
#10. Question 10: Breast Cancer Dataset
#Write a Python program to train a Gaussian Naïve Bayes classifier on the Breast Cancer
#dataset and evaluate accuracy.
#Hint:Use GaussianNB() from sklearn.naive_bayes and the Breast Cancer dataset from
#sklearn.datasets.
#Include your Python code and output in the code box below.)
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Load Breast Cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Gaussian Naïve Bayes classifier
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# Predictions
y_pred = gnb.predict(X_test)

# Accuracy
print("Accuracy of Gaussian Naïve Bayes:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy of Gaussian Naïve Bayes: 0.9415204678362573
